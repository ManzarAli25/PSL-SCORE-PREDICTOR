# %%
import pandas as pd
import numpy as np
import pickle

# %%
matches = pickle.load(open('dataset_level1.pkl','rb'))

# %%
matches
# Out:
#                                                innings    info.dates  \
# 0    [{'1st innings': {'team': 'Peshawar Zalmi', 'd...  [2017-02-09]
# 1    [{'1st innings': {'team': 'Quetta Gladiators',...  [2017-02-10]
# 2    [{'1st innings': {'team': 'Karachi Kings', 'de...  [2017-02-10]
# 3    [{'1st innings': {'team': 'Islamabad United', ...  [2017-02-11]
# 4    [{'1st innings': {'team': 'Karachi Kings', 'de...  [2017-02-11]
# ..                                                 ...           ...
# 209  [{'1st innings': {'team': 'Lahore Qalandars', ...  [2016-02-17]
# 210  [{'1st innings': {'team': 'Quetta Gladiators',...  [2016-02-19]
# 211  [{'1st innings': {'team': 'Karachi Kings', 'de...  [2016-02-20]
# 212  [{'1st innings': {'team': 'Islamabad United', ...  [2016-02-21]
# 213  [{'1st innings': {'team': 'Quetta Gladiators',...  [2016-02-23]
#
#     info.match_type info.outcome.winner  info.overs  info.player_of_match  \
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming matches is your DataFrame containing match information
# For example, matches = pd.read_csv('your_data.csv')

# Replace 'info.outcome.winner' with the actual column name containing winner team names
winner_counts = matches['info.outcome.winner'].value_counts()

# Plotting the number of wins for each team
plt.figure(figsize=(10, 6))
winner_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Wins for Each Team')
plt.xlabel('Team')
plt.ylabel('Number of Wins')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 12
#      10 # Plotting the number of wins for each team
#      11 plt.figure(figsize=(10, 6))
# ---> 12 winner_counts.plot(kind='pie', color='skyblue')
#      13 plt.title('Number of Wins for Each Team')
#      14 plt.xlabel('Team')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
winner_counts = matches['info.outcome.winner'].value_counts()

# %%
number_of_wins = {}
for team in winner_counts.index:
    number_of_wins[team] = winner_counts[team]

# Now x_val is a dictionary with teams as keys and win counts as values
number_of_wins
# Out:
# {'Peshawar Zalmi': 42,
#  'Islamabad United': 41,
#  'Quetta Gladiators': 36,
#  'Lahore Qalandars': 30,
#  'Multan Sultans': 30,
#  'Karachi Kings': 29}

# %%
x_val
# Out:
# ['Peshawar Zalmi',
#  'Islamabad United',
#  'Quetta Gladiators',
#  'Lahore Qalandars',
#  'Multan Sultans',
#  'Karachi Kings']

# %%
diction
# Out:
# {1: 2, 2: 3, 4: 6}

# %%
inn1 = pickle.load(open('battingrecord.pkl','rb'))
inn2 = pickle.load(open('battingrecord2.pkl','rb'))

# %%
inn1['batsman'].unique()
# Out:
# array(['Mohammad Hafeez', 'Kamran Akmal', 'DJ Malan', 'EJG Morgan',
#        'Haris Sohail', 'DJG Sammy', 'Shahid Afridi', 'CJ Jordan',
#        'Iftikhar Ahmed', 'Hasan Ali', 'Asad Shafiq', 'Ahmed Shehzad',
#        'KP Pietersen', 'RR Rossouw', 'Sarfraz Ahmed',
#        'Mohammad Nawaz (3)', 'NLTC Perera', 'Hassan Khan', 'Anwar Ali',
#        'TS Mills', 'Shahzaib Hasan', 'CH Gayle', 'Babar Azam',
#        'KC Sangakkara', 'Shoaib Malik', 'RS Bopara', 'KA Pollard',
#        'Imad Wasim', 'Mohammad Amir', 'DR Smith', 'SW Billings',
#        'BJ Haddin', 'Misbah-ul-Haq', 'SR Watson', 'Asif Ali',
#        'Shadab Khan', 'Mohammad Sami', 'Sohail Khan', 'JJ Roy',
#        'BB McCullum', 'Umar Akmal', 'Fakhar Zaman', 'GD Elliott',
#        'Mohammad Rizwan', 'SP Narine', 'Sohail Tanvir', 'Bilawal Bhatti',
#        'Mohammad Irfan (4)', 'Mahmudullah', 'Tamim Iqbal',
#        'Sohaib Maqsood', 'Imran Khalid', 'CS Delport', 'Shakib Al Hasan',
# ...

# %%
inn1
# Out:
#        match_id                                  teams       batting_team  \
# 0             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 1             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 2             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 3             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# 4             2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi
# ...         ...                                    ...                ...
# 25499       215  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 25500       215  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 25501       215  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 25502       215  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
# 25503       215  [Quetta Gladiators, Islamabad United]  Quetta Gladiators
#
#        ball          batsman          bowler  runs player_dismissed city  \
# ...

# %%
batting_data = inn1[['batsman', 'runs']]

# Group by batsman and sum the runs for each batsman
batting_record_1st = batting_data.groupby('batsman')['runs'].sum().reset_index()

# Rename the columns as per your requirement
batting_record_1st.columns = ['batsman', 'total_runs']

# Print or display the new DataFrame
batting_record_1st
# Out:
#             batsman  total_runs
# 0            A Lyth           9
# 1    AB de Villiers         123
# 2          AD Hales         366
# 3        AD Russell         108
# 4      ADS Fletcher          85
# ..              ...         ...
# 242     Zafar Gohar          29
# 243   Zahid Mahmood          35
# 244  Zeeshan Ashraf         172
# 245     Zohaib Khan           8
# 246  Zulfiqar Babar          21
#
# [247 rows x 2 columns]

# %%
# Find the batsman with the highest total runs
max_runs_batsman = batting_record.loc[batting_record['total_runs'].idxmax()]

# Display the result
print("Batsman with the most total runs:")
print(max_runs_batsman['batsman'])
print("Total Runs:", max_runs_batsman['total_runs'])
# Out:
# Batsman with the most total runs:
# Kamran Akmal
# Total Runs: 1147

# %%
batting_data = inn2[['batsman', 'runs']]

# Group by batsman and sum the runs for each batsman
batting_record_2nd = batting_data.groupby('batsman')['runs'].sum().reset_index()

# Rename the columns as per your requirement
batting_record_2nd.columns = ['batsman', 'total_runs']

# Print or display the new DataFrame
batting_record_2nd
# Out:
#             batsman  total_runs
# 0            A Lyth          51
# 1    AB de Villiers         103
# 2          AD Hales         573
# 3        AD Russell          74
# 4      ADS Fletcher          76
# ..              ...         ...
# 243      Zahir Khan          12
# 244      Zaman Khan           1
# 245  Zeeshan Ashraf          63
# 246     Zohaib Khan          10
# 247  Zulfiqar Babar           3
#
# [248 rows x 2 columns]

# %%
    pickle.dump(batting_record_2nd,open( 'second_inning_batters.pkl','wb'))

pickle.dump(batting_record_1st,open('first_inning_batters.pkl','wb'))

# %%
first_inning = pickle.load(open('first_innings.pkl','rb'))

# %%
first_inning
# Out:
#             batting_team       bowling_team       city  current_score  \
# 12791     Multan Sultans      Karachi Kings     Lahore             53
# 17522     Multan Sultans  Quetta Gladiators  Abu Dhabi             68
# 16666  Quetta Gladiators   Islamabad United  Abu Dhabi             75
# 13501   Lahore Qalandars      Karachi Kings    Karachi            141
# 6264    Islamabad United      Karachi Kings    Sharjah             61
# ...                  ...                ...        ...            ...
# 569        Karachi Kings  Quetta Gladiators      Dubai             85
# 4463       Karachi Kings   Islamabad United    Sharjah            117
# 3965   Quetta Gladiators     Peshawar Zalmi    Sharjah             67
# 18272      Karachi Kings     Peshawar Zalmi  Abu Dhabi             48
# 4408       Karachi Kings   Islamabad United    Sharjah             38
#
#        balls_left  wickets_left       crr  last_five  total_score
# ...

# %%
first_inning['city'].unique()
# Out:
# array(['Lahore', 'Abu Dhabi', 'Karachi', 'Sharjah', 'Dubai', 'Rawalpindi',
#        'Multan'], dtype=object)
